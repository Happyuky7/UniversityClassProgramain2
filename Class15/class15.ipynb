# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('flights.csv')
print(df.head())
print(df.tail())
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121
#      year      month  passengers
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432

# %% [markdown]
# # 2.3 Primeros graficos exploratorios (barras)

# %%
plt.bar(df.year, df.passengers)
plt.show()

# %% [markdown]
# # 2.4 Primeros filtros

# %%
df['passengers'][df['passengers'] > 500]
# Out:
# 115    505
# 126    548
# 127    559
# 137    535
# 138    622
# 139    606
# 140    508
# Name: passengers, dtype: int64

# %% [markdown]
# # 2.5 Grafico de histograma

# %%
plt.hist(df['passengers'], bins=10)
plt.show()

plt.hist(df['passengers'], bins=20)
plt.show()

plt.hist(df['passengers'], bins=50)
plt.show()

plt.hist(df['passengers'], bins=100)
plt.show()

plt.hist(df['passengers'], bins=200)
plt.show()

# %%
df['underperforming'] = 0
df.head()
# Out:
#    year     month  passengers  underperforming
# 0  1949   January         112                0
# 1  1949  February         118                0
# 2  1949     March         132                0
# 3  1949     April         129                0
# 4  1949       May         121                0

# %%
df2 = pd.DataFrame({'Nombre': ['Juan', 'Pedro', 'Maria'], 'Edad': [25, 30, 35]})
print(df2)
# Out:
#   Nombre  Edad
# 0   Juan    25
# 1  Pedro    30
# 2  Maria    35

# %%
for index, row in df2.iterrows():
    print('Ojo imprimo usando el indice ', index, ':',
            row['Nombre'], 'tiene', row['Edad'], 'años')
# Out:
# Ojo imprimo usando el indice  0 : Juan tiene 25 años
# Ojo imprimo usando el indice  1 : Pedro tiene 30 años
# Ojo imprimo usando el indice  2 : Maria tiene 35 años

# %%
asignacion = df2.at[0, 'Nombre']

print(f'El valor de la asignacion es {asignacion}')
# Out:
# El valor de la asignacion es Juan

# %%
media_pas = df.passengers.mean()
print(media_pas)
# Out:
# 280.2986111111111

# %%
for indice, filas in df.iterrows():
    if df['passengers'][indice] < media_pas:
        df.at[indice, 'underperforming'] = 1

# %%
df[(df['passengers'] > media_pas) & (df['year'] < 1955)]
# Out:
#     year   month  passengers  underperforming
# 66  1954    July         302                0
# 67  1954  August         293                0

# %%
# Encontrar los underperforming, despues de 1954

df[(df['underperforming'] == 1) & (df['year'] > 1954)]
# Out:
#     year     month  passengers  underperforming
# 72  1955   January         242                1
# 73  1955  February         233                1
# 74  1955     March         267                1
# 75  1955     April         269                1
# 76  1955       May         270                1
# 81  1955   October         274                1
# 82  1955  November         237                1
# 83  1955  December         278                1
# 85  1956  February         277                1
# 94  1956  November         271                1
